# %%
import pandas as pd
import numpy as np

# %%
hn = pd.read_csv('/users/andeladeveloper/D3/python-projects/Data Engineering/HN_posts_year_to_Sep_26_2016.csv');
hn
# Out:
#               id                                              title  \
# 0       12579008  You have two days to comment if you want stem ...
# 1       12579005                         SQLAR  the SQLite Archiver
# 2       12578997  What if we just printed a flatscreen televisio...
# 3       12578989                                  algorithmic music
# 4       12578979  How the Data Vault Enables the Next-Gen Data W...
# ...          ...                                                ...
# 293114  10176919        Ask HN: What is/are your favorite quote(s)?
# 293115  10176917  Attention and awareness in stage magic: turnin...
# 293116  10176908                  Dying vets fuck you letter (2013)
# 293117  10176907  PHP 7 Coolest Features: Space Ships, Type Hint...
# 293118  10176903  Toyota Establishes Research Centers with MIT a...
#
#                                                       url  num_points  \
# 0       http://www.regulations.gov/document?D=FDA-2015...           1
# ...

# %%
len(hn)
# Out:
# 293119

# %%
hn.num_comments.sum()
# Out:
# 1912761

# %%
hn.num_comments.max()
# Out:
# 2531

# %%
hn.num_comments.min()
# Out:
# 0

# %%
hn.num_comments.mean()
# Out:
# 6.5255442328883495

# %%
hn.num_comments.std()
# Out:
# 30.376319445418506

# %%
hn.num_comments.percentile?
# Out:
# Object `hn.num_comments.percentile` not found.

# %%
total_sum_comments = hn.num_comments.sum()

# %%
avg_show_comments = hn.num_comments.mean()

# %%
### Post with the highest comments
post_with_highest_comment = hn[hn.num_comments == hn.num_comments.max()]

# %%
post_with_highest_comment
# Out:
#              id                 title  \
# 69169  11966167  UK votes to leave EU
#
#                                                   url  num_points  \
# 69169  http://www.bbc.co.uk/news/uk-politics-36615028        3125
#
#        num_comments   author      created_at
# 69169          2531  dmmalam  6/24/2016 3:48

# %%
### Height post comment author

post_with_highest_comment.author
# Out:
# 69169    dmmalam
# Name: author, dtype: object

# %%
hn.head(5)
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# ...

# %%
hn.columns
# Out:
# Index(['id', 'title', 'url', 'num_points', 'num_comments', 'author',
#        'created_at'],
#       dtype='object')

# %%
post_starts_ask_hn = hn.apply(lambda x: x.title.startswith('Ask HN'), axis=1)

# %%
post_starts_ask_hn
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 293114     True
# 293115    False
# 293116    False
# 293117    False
# 293118    False
# Length: 293119, dtype: bool

# %%
post_starts_ask_hn = hn[hn.apply(lambda x: x.title.startswith('Ask HN'), axis=1)]

# %%
post_starts_ask_hn
# Out:
#               id                                              title  url  \
# 10      12578908  Ask HN: What TLD do you use for local developm...  NaN
# 42      12578522  Ask HN: How do you pass on your work when you ...  NaN
# 76      12577908  Ask HN: How a DNS problem can be limited to a ...  NaN
# 80      12577870  Ask HN: Why join a fund when you can be an angel?  NaN
# 102     12577647  Ask HN: Someone uses stock trading as passive ...  NaN
# ...          ...                                                ...  ...
# 293047  10177359  Ask HN: Is coursera specialization in product ...  NaN
# 293052  10177317  Ask HN: Any meteor devs out there who could sp...  NaN
# 293055  10177309  Ask HN: Any recommendations for books about ra...  NaN
# 293073  10177200  Ask HN: Where do you look for work if you need...  NaN
# 293114  10176919        Ask HN: What is/are your favorite quote(s)?  NaN
#
#         num_points  num_comments          author       created_at
# ...

# %%
show_posts_hn = hn[hn.apply(lambda x: x.title.startswith('Show HN'), axis=1)]

# %%
show_posts_hn
# Out:
#               id                                              title  \
# 52      12578335              Show HN: Finding puns computationally
# 58      12578182  Show HN: A simple library for complicated anim...
# 64      12578098      Show HN: WebGL visualization of DNA sequences
# 70      12577991  Show HN: Pomodoro-centric, heirarchical projec...
# 140     12577142  Show HN: Jumble  Essays on the go #PaulInYourP...
# ...          ...                                                ...
# 292995  10177714  Show HN: Repartee  The SMS Messaging Stack for...
# 293002  10177631  Show HN: Immutable and type-checked state and ...
# 293019  10177511  Show HN: MockTheClock  A tiny JavaScript libra...
# 293028  10177459  Show HN: AppyPaper  Gift wrap with app icons p...
# 293037  10177421  Show HN: Popularity scoring for arXiv publicat...
#
#                                                       url  num_points  \
# 52                          http://puns.samueltaylor.org/           2
# ...

# %%
neither_show_nor_ask = hn[hn.apply(lambda x: x.title.startswith('Show HN') != True or x.title.startswith('Ask HN') != True, axis=1)]

# %%
neither_show_nor_ask
# Out:
#               id                                              title  \
# 0       12579008  You have two days to comment if you want stem ...
# 1       12579005                         SQLAR  the SQLite Archiver
# 2       12578997  What if we just printed a flatscreen televisio...
# 3       12578989                                  algorithmic music
# 4       12578979  How the Data Vault Enables the Next-Gen Data W...
# ...          ...                                                ...
# 293114  10176919        Ask HN: What is/are your favorite quote(s)?
# 293115  10176917  Attention and awareness in stage magic: turnin...
# 293116  10176908                  Dying vets fuck you letter (2013)
# 293117  10176907  PHP 7 Coolest Features: Space Ships, Type Hint...
# 293118  10176903  Toyota Establishes Research Centers with MIT a...
#
#                                                       url  num_points  \
# 0       http://www.regulations.gov/document?D=FDA-2015...           1
# ...

# %%
#### Average number of comments for post_starts_ask_hn

print('The average comments for\n\nPost_starts_ask_hn: {0}\n\nShow_posts_hn: {1}\n\nNeither_show_nor_ask: {1}'.format(
    post_starts_ask_hn.num_comments.mean(),
    show_posts_hn.num_comments.mean(), neither_show_nor_ask.num_comments.mean()))
# Out:
# The average comments for
#
# Post_starts_ask_hn: 10.406709055031792
#
# Show_posts_hn: 4.888374384236453
#
# Neither_show_nor_ask: 4.888374384236453

# %%
post_starts_ask_hn
# Out:
#               id                                              title  url  \
# 10      12578908  Ask HN: What TLD do you use for local developm...  NaN
# 42      12578522  Ask HN: How do you pass on your work when you ...  NaN
# 76      12577908  Ask HN: How a DNS problem can be limited to a ...  NaN
# 80      12577870  Ask HN: Why join a fund when you can be an angel?  NaN
# 102     12577647  Ask HN: Someone uses stock trading as passive ...  NaN
# ...          ...                                                ...  ...
# 293047  10177359  Ask HN: Is coursera specialization in product ...  NaN
# 293052  10177317  Ask HN: Any meteor devs out there who could sp...  NaN
# 293055  10177309  Ask HN: Any recommendations for books about ra...  NaN
# 293073  10177200  Ask HN: Where do you look for work if you need...  NaN
# 293114  10176919        Ask HN: What is/are your favorite quote(s)?  NaN
#
#         num_points  num_comments          author       created_at
# ...

# %%
import datetime as dt
date_1_str = "December 24, 1984"
date_1_dt = dt.datetime.strptime(date_1_str, "%B %d, %Y")

# %%
date_1_dt
# Out:
# datetime.datetime(1984, 12, 24, 0, 0)

# %%
post_starts_ask_hn.apply(lambda x: dt.datetime.strptime(x.created_at, "%B/%d/%Y "), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-67c89143216b> in <module>
# ----> 1 post_starts_ask_hn.apply(lambda x: dt.datetime.strptime(x.created_at, "%B/%d/%Y "), axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
# ...
